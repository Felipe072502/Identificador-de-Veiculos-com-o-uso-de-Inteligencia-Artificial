# %% [markdown]
# integrantes:
#
# Felipe Nakandakari dos Santos - 10395160
#
# Luigi Uematsu - 10396148
#
#
# **Base de dados veículos Frota Nacional (Brasil) - atualizado em agosto 2024.**
#
# fonte: https://www.gov.br/transportes/pt-br/assuntos/transito/conteudo-Senatran/frota-de-veiculos-2024
#
#
# O Dataset inclui a quantidade de todos os veículos da Frota Nacional registrados até Agosto de 2024. A base foi tratada via powerquery do excel, onde foram categorizados as colunas em: UF, marca, modelo, ano de fabricação e quantidade de veículos.

# %%
# %cd /content/sample_data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel('Frota Veículos Brasil Agosto 2024.xlsx')
display(df)
# Out:
#             UF          Município   Marca                Modelo  \
# 0         ACRE         ACRELANDIA  AGRALE                 13000
# 1         ACRE         ACRELANDIA  AGRALE                  1800
# 2         ACRE         ACRELANDIA  AGRALE                  1800
# 3         ACRE         ACRELANDIA  AGRALE              1800D RD
# 4         ACRE         ACRELANDIA  AGRALE              1800D RD
# ...        ...                ...     ...                   ...
# 1048570  BAHIA  MARCIONILIO SOUZA     IMP         GM D20 DELUXE
# 1048571  BAHIA  MARCIONILIO SOUZA     IMP          KIA BESTA SV
# 1048572  BAHIA  MARCIONILIO SOUZA     IMP  MBENZ 310D SPRINTERM
# 1048573  BAHIA  MARCIONILIO SOUZA     IMP             VW GOL MI
# 1048574  BAHIA  MARCIONILIO SOUZA   IVECO       CITYCLASS 70C16
#
#          Ano Fabricação  Qtd. Veículos
# 0                2009.0             10
# 1                1989.0             10
# 2                1990.0             10
# 3                1989.0             10
# 4                1990.0             20
# ...                 ...            ...
# 1048570          1995.0             10
# 1048571          1994.0             10
# 1048572          1998.0             10
# 1048573          1998.0             10
# 1048574          2011.0             10
#
# [1048575 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Ano Fabricação'].plot(kind='hist', bins=20, title='Ano Fabricação')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Qtd. Veículos'].plot(kind='hist', bins=20, title='Qtd. Veículos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('UF').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Ano Fabricação', y='Qtd. Veículos', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Ano Fabricação'].plot(kind='line', figsize=(8, 4), title='Ano Fabricação')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Qtd. Veículos'].plot(kind='line', figsize=(8, 4), title='Qtd. Veículos')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['UF'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Ano Fabricação', y='UF', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['UF'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Qtd. Veículos', y='UF', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.head()
# Out:
#      UF   Município   Marca    Modelo  Ano Fabricação  Qtd. Veículos
# 0  ACRE  ACRELANDIA  AGRALE     13000          2009.0             10
# 1  ACRE  ACRELANDIA  AGRALE      1800          1989.0             10
# 2  ACRE  ACRELANDIA  AGRALE      1800          1990.0             10
# 3  ACRE  ACRELANDIA  AGRALE  1800D RD          1989.0             10
# 4  ACRE  ACRELANDIA  AGRALE  1800D RD          1990.0             20
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Ano Fabricação'].plot(kind='hist', bins=20, title='Ano Fabricação')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Qtd. Veículos'].plot(kind='hist', bins=20, title='Qtd. Veículos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Modelo').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='Ano Fabricação', y='Qtd. Veículos', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Qtd. Veículos']
#   ys = series['Ano Fabricação']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('Qtd. Veículos', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Modelo')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Modelo', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Qtd. Veículos')
# _ = plt.ylabel('Ano Fabricação')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Qtd. Veículos']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Qtd. Veículos'}, axis=1)
#               .sort_values('Qtd. Veículos', ascending=True))
#   xs = counted['Qtd. Veículos']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('Qtd. Veículos', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Modelo')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Modelo', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Qtd. Veículos')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['Ano Fabricação'].plot(kind='line', figsize=(8, 4), title='Ano Fabricação')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['Qtd. Veículos'].plot(kind='line', figsize=(8, 4), title='Qtd. Veículos')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_8['Modelo'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_8, x='Ano Fabricação', y='Modelo', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['Modelo'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='Qtd. Veículos', y='Modelo', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   UF              1048575 non-null  object
#  1   Município       1048575 non-null  object
#  2   Marca           1048575 non-null  object
#  3   Modelo          1045521 non-null  object
#  4   Ano Fabricação  1041566 non-null  float64
#  5   Qtd. Veículos   1048575 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 48.0+ MB

# %%
df.describe()
# Out:
#        Ano Fabricação  Qtd. Veículos
# count    1.041566e+06   1.048575e+06
# mean     2.007289e+03   5.427275e+01
# std      1.195492e+01   2.792258e+02
# min      1.926000e+03   1.000000e+01
# 25%      2.001000e+03   1.000000e+01
# 50%      2.010000e+03   1.000000e+01
# 75%      2.016000e+03   3.000000e+01
# max      2.024000e+03   4.065000e+04
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['Ano Fabricação'].plot(kind='hist', bins=20, title='Ano Fabricação')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Qtd. Veículos'].plot(kind='hist', bins=20, title='Qtd. Veículos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12.plot(kind='scatter', x='Ano Fabricação', y='Qtd. Veículos', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['Ano Fabricação'].plot(kind='line', figsize=(8, 4), title='Ano Fabricação')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Qtd. Veículos'].plot(kind='line', figsize=(8, 4), title='Qtd. Veículos')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.hist(figsize=(10, 8))
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(col)
# Out:
# UF
# Município
# Marca
# Modelo

# %%
df_numeric = df.select_dtypes(exclude=['object'])
df_numeric.corr()
# Out:
#                 Ano Fabricação  Qtd. Veículos
# Ano Fabricação        1.000000       0.046122
# Qtd. Veículos         0.046122       1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['Ano Fabricação'].plot(kind='hist', bins=20, title='Ano Fabricação')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Qtd. Veículos'].plot(kind='hist', bins=20, title='Qtd. Veículos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='Ano Fabricação', y='Qtd. Veículos', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Qtd. Veículos']
#   ys = series['Ano Fabricação']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_18.sort_values('Qtd. Veículos', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Qtd. Veículos')
# _ = plt.ylabel('Ano Fabricação')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Qtd. Veículos']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Qtd. Veículos'}, axis=1)
#               .sort_values('Qtd. Veículos', ascending=True))
#   xs = counted['Qtd. Veículos']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_19.sort_values('Qtd. Veículos', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Qtd. Veículos')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['Ano Fabricação'].plot(kind='line', figsize=(8, 4), title='Ano Fabricação')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['Qtd. Veículos'].plot(kind='line', figsize=(8, 4), title='Qtd. Veículos')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.isnull().sum()
# Out:
# UF                   0
# Município            0
# Marca                0
# Modelo            3054
# Ano Fabricação    7009
# Qtd. Veículos        0
# dtype: int64
